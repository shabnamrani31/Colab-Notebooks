# %% [markdown]
# <a href="https://colab.research.google.com/github/shabnamrani31/Colab-Notebooks/blob/master/evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from model import UniSkip, Encoder
from data_loader import DataLoader
#from vocab import load_dictionary
from config import *
from torch import nn
import _pickle as pkl
from torch.autograd import Variable
import torch
import glob
class UsableEncoder:
    print("hello shabnam")
    def __init__(self, loc='uni_skip.npz'):
      
        print("Preparing the DataLoader. Loading the word dictionary")
        
    file_list=glob.glob("gdrive/My Drive/Colab Notebooks/mdata/***.pkl")
  
    def load_dictionary(file_path ):
       
        with open(file_path, 'rb') as f:
        
            worddict = pkl.load(f)
            print(worddict )
        
            return worddict  
file_list=glob.glob("gdrive/My Drive/Colab Notebooks/mdata/***.pkl") 
for file_path in file_list:
   #print("i am printing")
    #worddict=load_dictionary(file_path) 
    d = DataLoader(sentences=[''], word_dict=load_dictionary(file_path))
    encoder = None 
     
    print("hello shabnam")
    loc='uni_skip.npz'
    print("Loading encoder from the saved model at {}".format(loc))
    model = UniSkip()
    model.load_state_dict(torch.load(loc, map_location=lambda storage, loc: storage))
    encoder = model.encoder
    if USE_CUDA:
        self.encoder('utf-8').strip().cuda(CUDA_DEVICE)
           
              

    print("hello shabnam")
    

    print("hello shabnam")
import numpy as np
sentence = []
print("hello shabnam")
file_list=glob.glob("gdrive/My Drive/Colab Notebooks/maldata/***.txt")
for file_path in file_list:
    with open(file_path) as f_input:
        sentence.append(f_input.readlines())
             
                    
        def encode(sentence):
            #ret[]
            #indices = [d.convert_sentence_to_indices(sentence) ]
            indices = torch.stack(sentence)
            indices, _ = encoder(indices)
            indices = indices.view(-1, self.encoder.thought_size)
            indices = indices.data.cpu().numpy()
            
            ret.extend(indices)
            ret = np.array(ret)
            np.save('utable.npy', ret)
        
            return ret
encode(text)
usable_encoder = UsableEncoder()
# Out:
# hello shabnam
# ...

# %%
def load_dictionary(file_path ):
       
    with open(file_path, 'rb') as f:
        
        worddict = pkl.load(f)
        print(worddict )
        
        return worddict
file_list=glob.glob("gdrive/My Drive/Colab Notebooks/mdata/***.pkl") 
for file_path in file_list:
   #print("i am printing")
    worddict=load_dictionary(file_path)
# Out:
# OrderedDict([('0000000000001110', 2), ('0000000000001100', 3), ('0000000000001101', 4), ('0000000000010001', 5), ('0000000000001111', 6), ('0000000000010000', 7), ('0000000000001010', 8), ('0000000000010010', 9), ('0000000000001011', 10), ('0000000010110110', 11), ('0000000000010011', 12), ('0000000000100010', 13), ('0000000000100111', 14), ('0000000000010101', 15), ('0000000000010100', 16), ('0000000000100011', 17), ('0000000000001001', 18), ('0000000000011010', 19), ('0000000000100101', 20), ('0000000000010110', 21), ('0000000000010111', 22), ('0000000001000011', 23), ('0000000000001000', 24), ('0000000000011000', 25), ('0000000000111100', 26), ('0000000000011011', 27), ('0000000010110111', 28), ('0000000011000100', 29), ('0000000001010000', 30), ('0000000000011001', 31), ('0000000001000101', 32), ('0000000011010010', 33), ('0000000000011101', 34), ('0000000000100000', 35), ('0000000000111111', 36), ('0000000001000010', 37), ('0000000010110001', 38), ('0000000000100100', 39), ('000
# ...

# %%
from model import UniSkip, Encoder
from data_loader import DataLoader
#from vocab import load_dictionary
from config import *
from torch import nn
import _pickle as pkl

from torch.autograd import Variable
import torch
import glob
class UsableEncoder:

    def __init__(self, loc="uni_skip.npz"):
      
        print("Preparing the DataLoader. Loading the word dictionary")
        file_list=glob.glob("gdrive/My Drive/Colab Notebooks/mdata/***.pkl") 
        for file_path in file_list:
   #print("i am printing")
    #worddict=load_dictionary(file_path) 
            self.d = DataLoader(sentences=[''], word_dict=load_dictionary(file_path))
            self.encoder = None 
        return worddict   
    print("hello shabnam")
    file_list=glob.glob("gdrive/My Drive/Colab Notebooks/maldata/***.txt") 
    for file_path1 in file_list:
        print("Loading encoder from the saved model at {}".format(file_path1))
        file_path1='uni_skip.npz'
        model = UniSkip()
        model.load_state_dict(torch.load(file_path1, map_location=lambda storage, file_path1: storage))
        self.encoder = model.encoder('utf-8').strip()
        if USE_CUDA:
            self.encoder('utf-8').strip().cuda(CUDA_DEVICE)
def load_dictionary(file_path ):
       
    with open(file_path, 'rb') as f:
        
        worddict = pkl.load(f)
        print(worddict )
        
        return worddict
file_list=glob.glob("gdrive/My Drive/Colab Notebooks/mdata/***.pkl") 
for file_path in file_list:
   #print("i am printing")
    worddict=load_dictionary(file_path) 


    print("Loading encoder from the saved model at {}".format(loc))
    model = UniSkip()
    model.load_state_dict(torch.load(loc, map_location=lambda storage, loc: storage))
    self.encoder = model.encoder
    if USE_CUDA:
        self.encoder.cuda(CUDA_DEVICE)
    
import numpy as np
corpus = []
print("hello shabnam")
for file_path in file_list:
    with open(file_path) as f_input:
        corpus.append(f_input.readlines())
             
                    
        def encode(corpus):
            #ret[]
            indices = [d.convert_sentence_to_indices(sentence) ]
            indices = torch.stack(indices)
            indices, _ = encoder(indices)
            indices = indices.view(-1, self.encoder.thought_size)
            indices = indices.data.cpu().numpy()
            
            ret.extend(indices)
            ret = np.array(ret)
            np.save('utable.npy', ret)
        
            return ret
encode(text)
usable_encoder = UsableEncoder()
# Out:
# hello shabnam
# Loading encoder from the saved model at gdrive/My Drive/Colab Notebooks/maldata/000014F7037586315DE348D21337B90B83A1C887E247DA8E4CC043702E36DFBA.apk.txt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-194-1d510c67c17c> in <module>()
#       9 import torch
#      10 import glob
# ---> 11 class UsableEncoder:
#      12
#      13     def __init__(self, loc="uni_skip.npz"):
#
# <ipython-input-194-1d510c67c17c> in UsableEncoder()
#      28         model = UniSkip()
#      29         model.load_state_dict(torch.load(file_path1, map_location=lambda storage, file_path1: storage))
# ---> 30         self.encoder = model.encoder
#      31         if USE_CUDA:
#      32             self.encoder('utf-8').strip().cuda(CUDA_DEVICE)
#
# NameError: name 'self' is not defined

# %%
import numpy as np
corpus = []
print("hello shabnam")
file_list=glob.glob("gdrive/My Drive/Colab Notebooks/maldata/***.txt") 
for file_path in file_list:
    with open(file_path) as f_input:
        corpus.append(f_input.readlines())
             
                    
        def encode(corpus):
            #ret[]
            indices = [d.convert_sentence_to_indices(corpus) ]
            indices = torch.stack(indices)
            indices, _ = encoder(indices)
            indices = indices.view(-1, self.encoder.thought_size)
            indices = indices.data.cpu().numpy()
            
            ret.extend(indices)
            ret = np.array(ret)
            np.save('utable.npy', ret)
        
            return ret

      
encode(text)
# Out:
# hello shabnam
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-185-249df9b5d08e> in <module>()
#      23
#      24
# ---> 25 encode(text)
#
# <ipython-input-185-249df9b5d08e> in encode(corpus)
#      10         def encode(corpus):
#      11             #ret[]
# ---> 12             indices = [d.convert_sentence_to_indices(corpus) ]
#      13             indices = torch.stack(indices)
#      14             indices, _ = encoder(indices)
#
# /content/data_loader.py in convert_sentence_to_indices(self, sentence)
#      44                       self.word_dict.get(w) if self.word_dict.get(w, VOCAB_SIZE + 1) < VOCAB_SIZE else self.UNK
#      45
# ---> 46                       for w in sentence  # split into words on spaces
#      47                   ][: self.maxlen - 1]  # take only maxlen-1 words per sentence at the most.
#      48
#
# ...

# %%
# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch

# %%
import glob
import os
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch

# %%
import glob
import os
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import glob
import os
from google.colab import drive

file_list=glob.glob("gdrive/My Drive/Colab Notebooks/maldata/***.txt")

corpus = []

for file_path in file_list:
    with open(file_path) as f_input:
        corpus.append(f_input.readlines())
        d = DataLoader(file_path)
# Out:
# Loading text file at gdrive/My Drive/Colab Notebooks/maldata/000014F7037586315DE348D21337B90B83A1C887E247DA8E4CC043702E36DFBA.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/maldata/000014F7037586315DE348D21337B90B83A1C887E247DA8E4CC043702E36DFBA.apk.txt.pkl
# dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/maldata/00001AC7364E668F1DDC9906887EDF0C8F7230830B864DB6179075AC9C0A6892.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 115 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/maldata/00001AC7364E668F1DDC9906887EDF0C8F7230830B864DB6179075AC9C0A6892.apk.txt.pkl
# dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/maldata/00001C3DDD0FA4797DAC37098FC4F1609D50B2E6BE61213CA0BA8F38C02049CF.apk.txt
# Making dictionary for these words
# ...

# %%
import glob
import os
from google.colab import drive

file_list=glob.glob("gdrive/My Drive/Colab Notebooks/mdata/***.txt")

corpus = []

for file_path in file_list:
    with open(file_path) as f_input:
        corpus.append(f_input.readlines())
        d = DataLoader(file_path)
