# %% [markdown]
# <a href="https://colab.research.google.com/github/shabnamrani31/Colab-Notebooks/blob/master/Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch
# Out:
# tcmalloc: large alloc 1073750016 bytes == 0x57a78000 @  0x7f988ef402a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641

# %%
import torch
print(torch.cuda.is_available())

from torch import nn
from torch.autograd import Variable

from data_loader import DataLoader
from model import UniSkip
from config import *
from datetime import datetime, timedelta
torch.cuda.set_device(0)
from google.colab import files
# Out:
# True
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-2bcaebfbff96> in <module>()
#       5 from torch.autograd import Variable
#       6
# ----> 7 from data_loader import DataLoader
#       8 from model import UniSkip
#       9 from config import *
#
# ModuleNotFoundError: No module named 'data_loader'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch
# Out:
# tcmalloc: large alloc 1073750016 bytes == 0x57a30000 @  0x7f4dfd8302a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641

# %%
# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch
# Out:
# tcmalloc: large alloc 1073750016 bytes == 0x579ac000 @  0x7f736d7812a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641

# %%
import glob
import os
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

#file_list =  glob.glob(os.path.join(os.getcwd(), mdata, "*.txt"))


#print (corpus)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # New Section

# %%
import glob
import os
from google.colab import drive

file_list=glob.glob("gdrive/My Drive/Colab Notebooks/mdata/***.txt")

corpus = []

for file_path in file_list:
    with open(file_path) as f_input:
        corpus.append(f_input.readlines())
        d = DataLoader(file_path)
#sentences = f.readlines()
# Out:
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/000014F7037586315DE348D21337B90B83A1C887E247DA8E4CC043702E36DFBA.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/000014F7037586315DE348D21337B90B83A1C887E247DA8E4CC043702E36DFBA.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/000014F7037586315DE348D21337B90B83A1C887E247DA8E4CC043702E36DFBA.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00001AC7364E668F1DDC9906887EDF0C8F7230830B864DB6179075AC9C0A6892.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 115 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00001AC7364E668F1DDC9906887EDF0C8F7230830B864DB6179075AC9C0A6892.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00001AC7364E668F1DDC9906887EDF0C8F7230830B864DB6179075AC9C0A6892.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/000049F9C8B2421F186FB9E4E02852B2F51DDF6301E14FE0C5133CA17E45B28C.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 253 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/000049F9C8B2421F186FB9E4E02852B2F51DDF6301E14FE0C5133CA17E45B28C.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/000049F9C8B2421F186FB9E4E02852B2F51DDF6301E14FE0C5133CA17E45B28C.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0000ABE9DF732ABF0DFCB9BF5BCF78F935454CDC17867AFC1A73E74E931C3185.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000ABE9DF732ABF0DFCB9BF5BCF78F935454CDC17867AFC1A73E74E931C3185.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000ABE9DF732ABF0DFCB9BF5BCF78F935454CDC17867AFC1A73E74E931C3185.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00001C429E58E2795B815F0EB63C603837AFC0EE76E9AE633C27021E11435BB2.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00001C429E58E2795B815F0EB63C603837AFC0EE76E9AE633C27021E11435BB2.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00001C429E58E2795B815F0EB63C603837AFC0EE76E9AE633C27021E11435BB2.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00002DC4C5EB5B50DF52649F58927903F4E1ADF1D0F29435F44606F2740A667E.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00002DC4C5EB5B50DF52649F58927903F4E1ADF1D0F29435F44606F2740A667E.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00002DC4C5EB5B50DF52649F58927903F4E1ADF1D0F29435F44606F2740A667E.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00009D535D4B429F0DD0B505A3A3645F0D28EF023AF91D44A502E4BD10580CE0.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00009D535D4B429F0DD0B505A3A3645F0D28EF023AF91D44A502E4BD10580CE0.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00009D535D4B429F0DD0B505A3A3645F0D28EF023AF91D44A502E4BD10580CE0.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00008B28A5312BA8E059D32630C5AA2F6302FF7993D0D3C4B59521646104533B.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00008B28A5312BA8E059D32630C5AA2F6302FF7993D0D3C4B59521646104533B.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00008B28A5312BA8E059D32630C5AA2F6302FF7993D0D3C4B59521646104533B.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00001F58C32E40376F64CC88B70F8FAD2FDA054E0863ABD5E41F4C6F18A65DA2.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00001F58C32E40376F64CC88B70F8FAD2FDA054E0863ABD5E41F4C6F18A65DA2.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00001F58C32E40376F64CC88B70F8FAD2FDA054E0863ABD5E41F4C6F18A65DA2.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00001C3DDD0FA4797DAC37098FC4F1609D50B2E6BE61213CA0BA8F38C02049CF.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00001C3DDD0FA4797DAC37098FC4F1609D50B2E6BE61213CA0BA8F38C02049CF.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00001C3DDD0FA4797DAC37098FC4F1609D50B2E6BE61213CA0BA8F38C02049CF.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0000D3E05CFAD4C3F301F8B47986354AACA80AC236C5934EC287D91E3EFC037B.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 219 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000D3E05CFAD4C3F301F8B47986354AACA80AC236C5934EC287D91E3EFC037B.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000D3E05CFAD4C3F301F8B47986354AACA80AC236C5934EC287D91E3EFC037B.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00015BBC4B822B1EAD01DDF3B64D52DF13A3A64271F58EB1151BF1AA7C3CD6F8.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 210 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00015BBC4B822B1EAD01DDF3B64D52DF13A3A64271F58EB1151BF1AA7C3CD6F8.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00015BBC4B822B1EAD01DDF3B64D52DF13A3A64271F58EB1151BF1AA7C3CD6F8.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0000DD8AAD7A9460592E73539E1C5C17CC5B8FC182B63B4F3640287249B30C4E.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000DD8AAD7A9460592E73539E1C5C17CC5B8FC182B63B4F3640287249B30C4E.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000DD8AAD7A9460592E73539E1C5C17CC5B8FC182B63B4F3640287249B30C4E.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00016A9CC8E89A55E827BC17B84FC9C0F23A5FF5B21ADA378688DDB3D64A16EF.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 152 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00016A9CC8E89A55E827BC17B84FC9C0F23A5FF5B21ADA378688DDB3D64A16EF.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00016A9CC8E89A55E827BC17B84FC9C0F23A5FF5B21ADA378688DDB3D64A16EF.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00010CC3C1C21C2583FD9E27947E20E7B80093CE3045970640BD76B8A0E1AC01.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00010CC3C1C21C2583FD9E27947E20E7B80093CE3045970640BD76B8A0E1AC01.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00010CC3C1C21C2583FD9E27947E20E7B80093CE3045970640BD76B8A0E1AC01.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00012CD91DEE2F7A419070F7CD18FBCBEC66B674D5F26C1C941A1FBCC29D4ACA.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 232 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00012CD91DEE2F7A419070F7CD18FBCBEC66B674D5F26C1C941A1FBCC29D4ACA.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00012CD91DEE2F7A419070F7CD18FBCBEC66B674D5F26C1C941A1FBCC29D4ACA.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00017ED2C044CAF7B1047184673EC3E11AB10AC0E64FB7E7BCCACA0DEB13198A.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 213 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00017ED2C044CAF7B1047184673EC3E11AB10AC0E64FB7E7BCCACA0DEB13198A.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00017ED2C044CAF7B1047184673EC3E11AB10AC0E64FB7E7BCCACA0DEB13198A.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0000D51EF7E4F82827DBAD75E1B95E2474913D3724AFCA6DF94426AB4319B19B.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 249 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000D51EF7E4F82827DBAD75E1B95E2474913D3724AFCA6DF94426AB4319B19B.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000D51EF7E4F82827DBAD75E1B95E2474913D3724AFCA6DF94426AB4319B19B.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00018BE05388F722B0DB83C6D394A0B78815866186077471FAE33B7BF1F4D26D.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 112 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00018BE05388F722B0DB83C6D394A0B78815866186077471FAE33B7BF1F4D26D.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00018BE05388F722B0DB83C6D394A0B78815866186077471FAE33B7BF1F4D26D.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/000002B63FAD4B030787F6DE4081DC1E12325026EB7DDAD146C52F5F4FC2D525.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/000002B63FAD4B030787F6DE4081DC1E12325026EB7DDAD146C52F5F4FC2D525.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/000002B63FAD4B030787F6DE4081DC1E12325026EB7DDAD146C52F5F4FC2D525.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00019A590B24449C7EA368B25D3143481311E4DE70CEF5D3B46B5C1809FD677C.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00019A590B24449C7EA368B25D3143481311E4DE70CEF5D3B46B5C1809FD677C.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00019A590B24449C7EA368B25D3143481311E4DE70CEF5D3B46B5C1809FD677C.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00011C10507671BC0E38A7161E6426717FED562E86DF54F35FCDFD6C5414B2B6.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00011C10507671BC0E38A7161E6426717FED562E86DF54F35FCDFD6C5414B2B6.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00011C10507671BC0E38A7161E6426717FED562E86DF54F35FCDFD6C5414B2B6.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0001A162A2A80F0C92DFD9FD8041CD82C4505CBDED43145AA8731652125339BB.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001A162A2A80F0C92DFD9FD8041CD82C4505CBDED43145AA8731652125339BB.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001A162A2A80F0C92DFD9FD8041CD82C4505CBDED43145AA8731652125339BB.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0000BBE2B06BD5B8A235CBE831DA507991657D2C3191D142ACFF6BBDED794833.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000BBE2B06BD5B8A235CBE831DA507991657D2C3191D142ACFF6BBDED794833.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000BBE2B06BD5B8A235CBE831DA507991657D2C3191D142ACFF6BBDED794833.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0001B814304242315FBA15B098E59EFBD30A7CC320C3A6DE755763271BA2FBB4.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001B814304242315FBA15B098E59EFBD30A7CC320C3A6DE755763271BA2FBB4.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001B814304242315FBA15B098E59EFBD30A7CC320C3A6DE755763271BA2FBB4.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0000E9EA6C0607AED06FEDF63A0529CC8E19314E910468B894DF10CA49035001.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000E9EA6C0607AED06FEDF63A0529CC8E19314E910468B894DF10CA49035001.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0000E9EA6C0607AED06FEDF63A0529CC8E19314E910468B894DF10CA49035001.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0001BFE0EEAAAB875623EBAFE77915BF7DC9A2A2772296356FC4A481DCCA96A1.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001BFE0EEAAAB875623EBAFE77915BF7DC9A2A2772296356FC4A481DCCA96A1.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001BFE0EEAAAB875623EBAFE77915BF7DC9A2A2772296356FC4A481DCCA96A1.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00022E427C310D919698C940D1A916B75877F1277A7930CD3E59969788AB4D09.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00022E427C310D919698C940D1A916B75877F1277A7930CD3E59969788AB4D09.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00022E427C310D919698C940D1A916B75877F1277A7930CD3E59969788AB4D09.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0079A46C9C02C2A92117CCD51C0BDABF837A96A8046D0B7968F553750313DC8A.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079A46C9C02C2A92117CCD51C0BDABF837A96A8046D0B7968F553750313DC8A.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079A46C9C02C2A92117CCD51C0BDABF837A96A8046D0B7968F553750313DC8A.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0079A56F16D47D2EE0DC2B7E718E13B09ABEE435D0F7A50579982BD063734C41.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079A56F16D47D2EE0DC2B7E718E13B09ABEE435D0F7A50579982BD063734C41.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079A56F16D47D2EE0DC2B7E718E13B09ABEE435D0F7A50579982BD063734C41.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0001EB7EBBC37659AB53EB82447477DC4D181319B3C3B32B618C5D602832E9FA.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001EB7EBBC37659AB53EB82447477DC4D181319B3C3B32B618C5D602832E9FA.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001EB7EBBC37659AB53EB82447477DC4D181319B3C3B32B618C5D602832E9FA.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0079B58CC7A4E551B083692666D70DCDE0D14E42DC2AD994FF86E4A6E43C2928.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079B58CC7A4E551B083692666D70DCDE0D14E42DC2AD994FF86E4A6E43C2928.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079B58CC7A4E551B083692666D70DCDE0D14E42DC2AD994FF86E4A6E43C2928.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00022B62869A8AB1F3B383B656AF785B27B04706C333F47B848BEC047ABAC77C.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00022B62869A8AB1F3B383B656AF785B27B04706C333F47B848BEC047ABAC77C.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00022B62869A8AB1F3B383B656AF785B27B04706C333F47B848BEC047ABAC77C.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0001C1F2A6FEF2F8C9CF7EE4C2F12030745F1F08D473D186A65CB4475957A3E4.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001C1F2A6FEF2F8C9CF7EE4C2F12030745F1F08D473D186A65CB4475957A3E4.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001C1F2A6FEF2F8C9CF7EE4C2F12030745F1F08D473D186A65CB4475957A3E4.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0001D703BDCAF7CF3110AB22F400D4FFD2E8C3FE805DE2C6D2F6D1E152BBFEC5.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 254 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001D703BDCAF7CF3110AB22F400D4FFD2E8C3FE805DE2C6D2F6D1E152BBFEC5.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001D703BDCAF7CF3110AB22F400D4FFD2E8C3FE805DE2C6D2F6D1E152BBFEC5.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0079B70F4D82CB912DA53DF34E55ECC2C564F2F0A72E37ABD6ACAA68AD3612F6.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079B70F4D82CB912DA53DF34E55ECC2C564F2F0A72E37ABD6ACAA68AD3612F6.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079B70F4D82CB912DA53DF34E55ECC2C564F2F0A72E37ABD6ACAA68AD3612F6.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00025D36A16900724D9266A4D1FC47AACAE17596201AF24BF41EB9CF4548C530.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00025D36A16900724D9266A4D1FC47AACAE17596201AF24BF41EB9CF4548C530.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00025D36A16900724D9266A4D1FC47AACAE17596201AF24BF41EB9CF4548C530.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0079C3A34F0DAFB511CA9184EDD5CCB8B2A13374B87A0594D37F34B34821C533.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079C3A34F0DAFB511CA9184EDD5CCB8B2A13374B87A0594D37F34B34821C533.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079C3A34F0DAFB511CA9184EDD5CCB8B2A13374B87A0594D37F34B34821C533.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00028E38310A3272B912031CED5539ECED44927DF330AA2881F8A1C1BAF47A40.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00028E38310A3272B912031CED5539ECED44927DF330AA2881F8A1C1BAF47A40.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00028E38310A3272B912031CED5539ECED44927DF330AA2881F8A1C1BAF47A40.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0079C7FCC4081A77302D7D6E9ED3964DA2451B772BC4593D67D29A669F338AD9.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079C7FCC4081A77302D7D6E9ED3964DA2451B772BC4593D67D29A669F338AD9.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079C7FCC4081A77302D7D6E9ED3964DA2451B772BC4593D67D29A669F338AD9.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00026E031AFEFAE7C3219DD6A5BCF63CB9F443DB608DB176AC08E26A51B391E8.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00026E031AFEFAE7C3219DD6A5BCF63CB9F443DB608DB176AC08E26A51B391E8.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00026E031AFEFAE7C3219DD6A5BCF63CB9F443DB608DB176AC08E26A51B391E8.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0079D2CE0A22688451BFF9C58B901E7C2DA91415D325E2D692497BADAA24108E.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079D2CE0A22688451BFF9C58B901E7C2DA91415D325E2D692497BADAA24108E.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0079D2CE0A22688451BFF9C58B901E7C2DA91415D325E2D692497BADAA24108E.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084A3A619123C95F0B17B518579FB1BC85665BEF4EFD243A89E58AEBB26F4F6.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 254 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084A3A619123C95F0B17B518579FB1BC85665BEF4EFD243A89E58AEBB26F4F6.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084A3A619123C95F0B17B518579FB1BC85665BEF4EFD243A89E58AEBB26F4F6.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084C678AB126B191EB47438C49FF2835C28F20C03BD01252F52D815E3CF3472.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084C678AB126B191EB47438C49FF2835C28F20C03BD01252F52D815E3CF3472.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084C678AB126B191EB47438C49FF2835C28F20C03BD01252F52D815E3CF3472.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084D428F143D4A2E3C18814C83AF617D0BCE02A34E78B83186D2D8E335F1E49.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084D428F143D4A2E3C18814C83AF617D0BCE02A34E78B83186D2D8E335F1E49.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084D428F143D4A2E3C18814C83AF617D0BCE02A34E78B83186D2D8E335F1E49.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084B9AACD21DA418AF0D9928A2B2B55259858C94434A8A81D0D2E076DFC8CDE.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084B9AACD21DA418AF0D9928A2B2B55259858C94434A8A81D0D2E076DFC8CDE.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084B9AACD21DA418AF0D9928A2B2B55259858C94434A8A81D0D2E076DFC8CDE.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084DB1E1DC8AE66E4A46EE34872EA5051985A8AD55CACD12C9B4FE6CE44349D.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084DB1E1DC8AE66E4A46EE34872EA5051985A8AD55CACD12C9B4FE6CE44349D.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084DB1E1DC8AE66E4A46EE34872EA5051985A8AD55CACD12C9B4FE6CE44349D.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084BFCF10D07C569821CD6E76707B81FADD5E915A2F587CC08075DEC512C475.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084BFCF10D07C569821CD6E76707B81FADD5E915A2F587CC08075DEC512C475.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084BFCF10D07C569821CD6E76707B81FADD5E915A2F587CC08075DEC512C475.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084E7193DCF99D9316A72A900D817A4B2A9921D095638B10B861AC92F388E20.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084E7193DCF99D9316A72A900D817A4B2A9921D095638B10B861AC92F388E20.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084E7193DCF99D9316A72A900D817A4B2A9921D095638B10B861AC92F388E20.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0083F07C95FB7647BBDAC44ECBD798E27259E6C2DA873FA870C4B5AA063F9123.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0083F07C95FB7647BBDAC44ECBD798E27259E6C2DA873FA870C4B5AA063F9123.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0083F07C95FB7647BBDAC44ECBD798E27259E6C2DA873FA870C4B5AA063F9123.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084EC2427ADAB805B8727FA013A41335D5123DE49E18DBED3128B552D70F1E2.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084EC2427ADAB805B8727FA013A41335D5123DE49E18DBED3128B552D70F1E2.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084EC2427ADAB805B8727FA013A41335D5123DE49E18DBED3128B552D70F1E2.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084B4AD4C7308050423B3C9C95D0C80C897341310CE94D0CEE485CAEFFD2EC9.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084B4AD4C7308050423B3C9C95D0C80C897341310CE94D0CEE485CAEFFD2EC9.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084B4AD4C7308050423B3C9C95D0C80C897341310CE94D0CEE485CAEFFD2EC9.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084EDC48F6E60045160875A52FAAC6F82282A1756C46562DDF5D4FD2ED762BC.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084EDC48F6E60045160875A52FAAC6F82282A1756C46562DDF5D4FD2ED762BC.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084EDC48F6E60045160875A52FAAC6F82282A1756C46562DDF5D4FD2ED762BC.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084F1A20FD97A23CBD336FFB5CDD7AD1F9F97A5E0B213EF361EFB571B8BCA30.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 189 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084F1A20FD97A23CBD336FFB5CDD7AD1F9F97A5E0B213EF361EFB571B8BCA30.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084F1A20FD97A23CBD336FFB5CDD7AD1F9F97A5E0B213EF361EFB571B8BCA30.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00000F8EE4F64324BA04356745E946152C2F43ECB63372E89DB79830BADAF1BA.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00000F8EE4F64324BA04356745E946152C2F43ECB63372E89DB79830BADAF1BA.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00000F8EE4F64324BA04356745E946152C2F43ECB63372E89DB79830BADAF1BA.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084D0AAC5630E99EE5F8ED0410868E510F41D43EDFCBF33A3A741B77B67229D.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084D0AAC5630E99EE5F8ED0410868E510F41D43EDFCBF33A3A741B77B67229D.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084D0AAC5630E99EE5F8ED0410868E510F41D43EDFCBF33A3A741B77B67229D.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084FB81084DFE727BBF0B2F376DF691A7BB8BB19AF47AB32AE5B5AA55F97CC9.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084FB81084DFE727BBF0B2F376DF691A7BB8BB19AF47AB32AE5B5AA55F97CC9.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084FB81084DFE727BBF0B2F376DF691A7BB8BB19AF47AB32AE5B5AA55F97CC9.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085A979316150755ACB7145567FA7AA5D4146F3D984586A7EF186EB1B6E9AB6.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085A979316150755ACB7145567FA7AA5D4146F3D984586A7EF186EB1B6E9AB6.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085A979316150755ACB7145567FA7AA5D4146F3D984586A7EF186EB1B6E9AB6.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084ABC95E64B448638CFBBA18DFE6C539777C209239E25FB26269CE4CD814AB.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084ABC95E64B448638CFBBA18DFE6C539777C209239E25FB26269CE4CD814AB.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084ABC95E64B448638CFBBA18DFE6C539777C209239E25FB26269CE4CD814AB.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085AAD38AB19F698D9698E37856C80EBAEE6DB06DCE58BE23832AF6EEBBE1A2.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085AAD38AB19F698D9698E37856C80EBAEE6DB06DCE58BE23832AF6EEBBE1A2.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085AAD38AB19F698D9698E37856C80EBAEE6DB06DCE58BE23832AF6EEBBE1A2.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0084B113D02117AC8225408D0C4EECBF55288D92D8683A542524F1E6A0F7E51F.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084B113D02117AC8225408D0C4EECBF55288D92D8683A542524F1E6A0F7E51F.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0084B113D02117AC8225408D0C4EECBF55288D92D8683A542524F1E6A0F7E51F.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085B11DCF68BACEB37ACA37A4B5EB4124A50EFBAD41A4C705C9788FC9AF7AC9.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085B11DCF68BACEB37ACA37A4B5EB4124A50EFBAD41A4C705C9788FC9AF7AC9.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085B11DCF68BACEB37ACA37A4B5EB4124A50EFBAD41A4C705C9788FC9AF7AC9.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085E0BF026A3B73AFCECA1321BBB95FDBEA4396290DDC9E65039B323F1DE0B7.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 94 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085E0BF026A3B73AFCECA1321BBB95FDBEA4396290DDC9E65039B323F1DE0B7.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085E0BF026A3B73AFCECA1321BBB95FDBEA4396290DDC9E65039B323F1DE0B7.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085F4C2BDA4EF0598B3F6F34172DDA3F4EEABAA909A01AB7623A68E44703780.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 153 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085F4C2BDA4EF0598B3F6F34172DDA3F4EEABAA909A01AB7623A68E44703780.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085F4C2BDA4EF0598B3F6F34172DDA3F4EEABAA909A01AB7623A68E44703780.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085E7EEF7AE5DC20756479508DA5519C90E7F3BA59D2E259425FA2BF069743B.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 124 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085E7EEF7AE5DC20756479508DA5519C90E7F3BA59D2E259425FA2BF069743B.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085E7EEF7AE5DC20756479508DA5519C90E7F3BA59D2E259425FA2BF069743B.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085F83CA1C995E3C0FEBA39A433C6F3F826602E5506CBD14ED516111BD5C823.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 152 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085F83CA1C995E3C0FEBA39A433C6F3F826602E5506CBD14ED516111BD5C823.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085F83CA1C995E3C0FEBA39A433C6F3F826602E5506CBD14ED516111BD5C823.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085B9817F46E53A4166212F00F502276431BCA010A5DC1478822AF0F94A0A55.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085B9817F46E53A4166212F00F502276431BCA010A5DC1478822AF0F94A0A55.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085B9817F46E53A4166212F00F502276431BCA010A5DC1478822AF0F94A0A55.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085F192E39FA1F5B489CC6C08C3DB60A2790E56CDA11F4E987E2D58A634D1DE.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085F192E39FA1F5B489CC6C08C3DB60A2790E56CDA11F4E987E2D58A634D1DE.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085F192E39FA1F5B489CC6C08C3DB60A2790E56CDA11F4E987E2D58A634D1DE.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00001A21E96C4D131B5DC27897E89D23FC35D6D75A4CE1B15D6D30A4E4FC60F1.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00001A21E96C4D131B5DC27897E89D23FC35D6D75A4CE1B15D6D30A4E4FC60F1.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00001A21E96C4D131B5DC27897E89D23FC35D6D75A4CE1B15D6D30A4E4FC60F1.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085F90BDD1460DD0890967FA125B225359A8B43E5B8C2691827C0FD5E7B7173.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085F90BDD1460DD0890967FA125B225359A8B43E5B8C2691827C0FD5E7B7173.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085F90BDD1460DD0890967FA125B225359A8B43E5B8C2691827C0FD5E7B7173.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085EF0D08220EEABC2EE423CEAE0E15C0763CF656F17F9DFF61A59B4FB53906.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085EF0D08220EEABC2EE423CEAE0E15C0763CF656F17F9DFF61A59B4FB53906.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085EF0D08220EEABC2EE423CEAE0E15C0763CF656F17F9DFF61A59B4FB53906.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085FD74010FF1F40E690BE00F84E883C4F5FB927A2E18295B79EF035F8F2188.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085FD74010FF1F40E690BE00F84E883C4F5FB927A2E18295B79EF035F8F2188.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085FD74010FF1F40E690BE00F84E883C4F5FB927A2E18295B79EF035F8F2188.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085DAC6567BC82966AB6365841234CEF41EC4E9B25405E9DFAD5C5D62851CDC.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085DAC6567BC82966AB6365841234CEF41EC4E9B25405E9DFAD5C5D62851CDC.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085DAC6567BC82966AB6365841234CEF41EC4E9B25405E9DFAD5C5D62851CDC.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0086B41090847981A2C222B6A4DD1BFC34C85143B8263FF149449FF921611F95.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0086B41090847981A2C222B6A4DD1BFC34C85143B8263FF149449FF921611F95.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0086B41090847981A2C222B6A4DD1BFC34C85143B8263FF149449FF921611F95.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085D243AC02877BE67873AEC0DF60CCD0B494279D19DD212B54E616412C8D4D.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085D243AC02877BE67873AEC0DF60CCD0B494279D19DD212B54E616412C8D4D.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085D243AC02877BE67873AEC0DF60CCD0B494279D19DD212B54E616412C8D4D.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0085EF2A831E47B6BC8DACF35FDC596AD99192EED6B122221479CD442478034F.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085EF2A831E47B6BC8DACF35FDC596AD99192EED6B122221479CD442478034F.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0085EF2A831E47B6BC8DACF35FDC596AD99192EED6B122221479CD442478034F.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/000026E846FFCF60E2A9E135251B4F411300E903DCE95D47989B24158E93BB3D.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/000026E846FFCF60E2A9E135251B4F411300E903DCE95D47989B24158E93BB3D.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/000026E846FFCF60E2A9E135251B4F411300E903DCE95D47989B24158E93BB3D.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0086BC99BC01BD1C3022311C60B6D1C248BA59E30473F9A50F581F89A83B7865.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0086BC99BC01BD1C3022311C60B6D1C248BA59E30473F9A50F581F89A83B7865.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0086BC99BC01BD1C3022311C60B6D1C248BA59E30473F9A50F581F89A83B7865.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0086D19347202E6027E0196E9361013FE0564B0124BADEB63CF1C54144FF7978.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 204 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0086D19347202E6027E0196E9361013FE0564B0124BADEB63CF1C54144FF7978.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0086D19347202E6027E0196E9361013FE0564B0124BADEB63CF1C54144FF7978.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0087A0F0AED071231DCE972790ED287B9A83F7837D9FC12161100D402E2B9048.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 253 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0087A0F0AED071231DCE972790ED287B9A83F7837D9FC12161100D402E2B9048.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0087A0F0AED071231DCE972790ED287B9A83F7837D9FC12161100D402E2B9048.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0086F19FB4C90613571FC135D845D6E07E3BEF4AC22FF35B562D528A1A9D9956.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0086F19FB4C90613571FC135D845D6E07E3BEF4AC22FF35B562D528A1A9D9956.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0086F19FB4C90613571FC135D845D6E07E3BEF4AC22FF35B562D528A1A9D9956.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0086F95837FBAEEB0EF4086D9636D5B8D15E1ACE47039B23FF8F06EFF6CE2AD4.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0086F95837FBAEEB0EF4086D9636D5B8D15E1ACE47039B23FF8F06EFF6CE2AD4.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0086F95837FBAEEB0EF4086D9636D5B8D15E1ACE47039B23FF8F06EFF6CE2AD4.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0087BAD6B828E2C02894509A7044C9D93C9B4BD18A4ABE2AE5FFEFFE055F7F54.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0087BAD6B828E2C02894509A7044C9D93C9B4BD18A4ABE2AE5FFEFFE055F7F54.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# ...
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001F98D003CD201247D24F493C2AC59AC9886CC9032ED7B3643475158FA2C9F.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001F98D003CD201247D24F493C2AC59AC9886CC9032ED7B3643475158FA2C9F.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0001FE4D942805A647626CDC4AC4C6EBC0562D30CD4B509D3581DCCDC6BCBA7F.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001FE4D942805A647626CDC4AC4C6EBC0562D30CD4B509D3581DCCDC6BCBA7F.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0001FE4D942805A647626CDC4AC4C6EBC0562D30CD4B509D3581DCCDC6BCBA7F.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00020E0DDFFDDE9C7F20C6908D78348B6BB9F4EBEDA52E1EE573530A4BD44F0F.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00020E0DDFFDDE9C7F20C6908D78348B6BB9F4EBEDA52E1EE573530A4BD44F0F.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00020E0DDFFDDE9C7F20C6908D78348B6BB9F4EBEDA52E1EE573530A4BD44F0F.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00020E57B76F13E2DA91B106FBD8DAA35BC27E7E6B28DD971BBB3178775B9179.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00020E57B76F13E2DA91B106FBD8DAA35BC27E7E6B28DD971BBB3178775B9179.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00020E57B76F13E2DA91B106FBD8DAA35BC27E7E6B28DD971BBB3178775B9179.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00021B789ED01678D3300D1FEE9BEFAEE7AEB721F81DB263644AB2B51E40E9CC.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00021B789ED01678D3300D1FEE9BEFAEE7AEB721F81DB263644AB2B51E40E9CC.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00021B789ED01678D3300D1FEE9BEFAEE7AEB721F81DB263644AB2B51E40E9CC.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00021D4D91813494EC42D6B965DE579BD1A9AB4FA9D85D81F4778242AE10CEE6.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00021D4D91813494EC42D6B965DE579BD1A9AB4FA9D85D81F4778242AE10CEE6.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00021D4D91813494EC42D6B965DE579BD1A9AB4FA9D85D81F4778242AE10CEE6.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00021E0B37DE43505C2BF8F34D6A1C6A6CE0FB383559EC54D5528E3F4D2EF90A.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00021E0B37DE43505C2BF8F34D6A1C6A6CE0FB383559EC54D5528E3F4D2EF90A.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00021E0B37DE43505C2BF8F34D6A1C6A6CE0FB383559EC54D5528E3F4D2EF90A.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00022C8E0FE9D845C0535669D117F36007C809FF6D2E01B1D9120840FDCC65DB.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00022C8E0FE9D845C0535669D117F36007C809FF6D2E01B1D9120840FDCC65DB.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00022C8E0FE9D845C0535669D117F36007C809FF6D2E01B1D9120840FDCC65DB.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00023D0FE45CBF1A33A43F09CA9ACC20265541B6BC64FAA0AC94896CA9C6C211.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00023D0FE45CBF1A33A43F09CA9ACC20265541B6BC64FAA0AC94896CA9C6C211.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00023D0FE45CBF1A33A43F09CA9ACC20265541B6BC64FAA0AC94896CA9C6C211.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00023D27FB82CF3A5B8043B5D3036DA02EB070B0015ABCB30CA7DAC199E2B5CE.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00023D27FB82CF3A5B8043B5D3036DA02EB070B0015ABCB30CA7DAC199E2B5CE.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00023D27FB82CF3A5B8043B5D3036DA02EB070B0015ABCB30CA7DAC199E2B5CE.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00024A35563D3C1373B20E579361D9AF11AD901DF6F957052465FD04BEEE9D90.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00024A35563D3C1373B20E579361D9AF11AD901DF6F957052465FD04BEEE9D90.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00024A35563D3C1373B20E579361D9AF11AD901DF6F957052465FD04BEEE9D90.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00024B4E5D35E9C670E7019C2A2FFDACC95274B6554CF1D9B256AA23F3A015A2.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00024B4E5D35E9C670E7019C2A2FFDACC95274B6554CF1D9B256AA23F3A015A2.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00024B4E5D35E9C670E7019C2A2FFDACC95274B6554CF1D9B256AA23F3A015A2.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00026A557B4A3252E0278A631CFEA9F7120F241EA8F3FD6EEE47D8D3904FF123.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00026A557B4A3252E0278A631CFEA9F7120F241EA8F3FD6EEE47D8D3904FF123.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00026A557B4A3252E0278A631CFEA9F7120F241EA8F3FD6EEE47D8D3904FF123.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00026A91B6CE71C9E93197FADAF31D5DFC9FACE0A1FCA83B6A2A4D9790C6BD43.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00026A91B6CE71C9E93197FADAF31D5DFC9FACE0A1FCA83B6A2A4D9790C6BD43.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00026A91B6CE71C9E93197FADAF31D5DFC9FACE0A1FCA83B6A2A4D9790C6BD43.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00026B5BA69D84234A229C2638D90FB4287B1C7E5DF5987F6E3028AA02EF1CD7.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00026B5BA69D84234A229C2638D90FB4287B1C7E5DF5987F6E3028AA02EF1CD7.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00026B5BA69D84234A229C2638D90FB4287B1C7E5DF5987F6E3028AA02EF1CD7.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00026D80EDAA8F357B57D599481960F2426287A15474902BEEBB26689C9BA5F5.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00026D80EDAA8F357B57D599481960F2426287A15474902BEEBB26689C9BA5F5.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00026D80EDAA8F357B57D599481960F2426287A15474902BEEBB26689C9BA5F5.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00027B48DDC9E93FD44CF41DBC511BAF77BEA9C0725DA344F608535B890E1150.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00027B48DDC9E93FD44CF41DBC511BAF77BEA9C0725DA344F608535B890E1150.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00027B48DDC9E93FD44CF41DBC511BAF77BEA9C0725DA344F608535B890E1150.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00027B79F42BB18ABAC8EA1C7419CA617BDBA4660382A8C5F480A7951724B94B.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00027B79F42BB18ABAC8EA1C7419CA617BDBA4660382A8C5F480A7951724B94B.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00027B79F42BB18ABAC8EA1C7419CA617BDBA4660382A8C5F480A7951724B94B.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00027EF37AF490F075641C7BE251BB4A6FD83957439959B8BB66CD4CA105DB67.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00027EF37AF490F075641C7BE251BB4A6FD83957439959B8BB66CD4CA105DB67.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00027EF37AF490F075641C7BE251BB4A6FD83957439959B8BB66CD4CA105DB67.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00028D3B0C60FFEC306924C9B77D5CE5CE0D0329B6BD4D48601F0F14CA639540.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00028D3B0C60FFEC306924C9B77D5CE5CE0D0329B6BD4D48601F0F14CA639540.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00028D3B0C60FFEC306924C9B77D5CE5CE0D0329B6BD4D48601F0F14CA639540.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00028DBBC38EAF41882369D45F17988F1E4A4A97BDCF03E467B1F52C47CAA709.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00028DBBC38EAF41882369D45F17988F1E4A4A97BDCF03E467B1F52C47CAA709.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00028DBBC38EAF41882369D45F17988F1E4A4A97BDCF03E467B1F52C47CAA709.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/00029ED31B25068381FD8587FA0976591C10377F704D306CC06783B22B882BE5.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/00029ED31B25068381FD8587FA0976591C10377F704D306CC06783B22B882BE5.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/00029ED31B25068381FD8587FA0976591C10377F704D306CC06783B22B882BE5.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0002A2E83ED0E9D2ECB1DF3E835FBC69DBFC91B271BE69068ED008A80D7163E5.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002A2E83ED0E9D2ECB1DF3E835FBC69DBFC91B271BE69068ED008A80D7163E5.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002A2E83ED0E9D2ECB1DF3E835FBC69DBFC91B271BE69068ED008A80D7163E5.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0002A4B3B4BE065DED24A305E0202BCBA8334B2EC8893C3F872B73573B7B02ED.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002A4B3B4BE065DED24A305E0202BCBA8334B2EC8893C3F872B73573B7B02ED.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002A4B3B4BE065DED24A305E0202BCBA8334B2EC8893C3F872B73573B7B02ED.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0002A4CF55A50FE5C8C8B0856311CE43428B8AA277CBAC1AF64CF54E46424552.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002A4CF55A50FE5C8C8B0856311CE43428B8AA277CBAC1AF64CF54E46424552.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002A4CF55A50FE5C8C8B0856311CE43428B8AA277CBAC1AF64CF54E46424552.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0002A59AF190B23CF2DE9D26619A0D109FACDF4FCA145058CDDD6F01AEB5DF47.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002A59AF190B23CF2DE9D26619A0D109FACDF4FCA145058CDDD6F01AEB5DF47.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002A59AF190B23CF2DE9D26619A0D109FACDF4FCA145058CDDD6F01AEB5DF47.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0002AA1132C338F415EB1A6A14EC9D1E843E8D5F934678CCEC0EA31D559FEC67.apk.txt
# Making dictionary for these words
# unable to load from cached, building fresh
# Got 255 unique words
# Saveing dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002AA1132C338F415EB1A6A14EC9D1E843E8D5F934678CCEC0EA31D559FEC67.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002AA1132C338F415EB1A6A14EC9D1E843E8D5F934678CCEC0EA31D559FEC67.apk.txt.pkl
# reverse dictionary saved
# Loading text file at gdrive/My Drive/Colab Notebooks/mdata/0002B343D2855494FB265C529E3A8AB468316143A8D64E810E19B78C4778B5F1.apk.txt
# Making dictionary for these words
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002B343D2855494FB265C529E3A8AB468316143A8D64E810E19B78C4778B5F1.apk.txt.pkl
# dictionary saved
# Making reverse dictionary
# Using cached dictionary at gdrive/My Drive/Colab Notebooks/mdata/0002B343D2855494FB265C529E3A8AB468316143A8D64E810E19B78C4778B5F1.apk.txt.pkl
# reverse dictionary saved

# %%
d = DataLoader(corpus)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bdf6bb9e486d> in <module>()
# ----> 1 d = DataLoader(corpus)
#
# NameError: name 'corpus' is not defined

# %%
mod = UniSkip()

# %%
lr = 3e-4
optimizer = torch.optim.Adam(params=mod.parameters(), lr=lr)

# %%
from google.colab import files
import pickle

loss_trail = []
last_best_loss = None
current_time = datetime.utcnow()

def debug(i, loss, prev, nex, prev_pred, next_pred):
    global loss_trail
    global last_best_loss
    global current_time

    this_loss = loss.data[0]
    loss_trail.append(this_loss)
    loss_trail = loss_trail[-20:]
    new_current_time = datetime.utcnow()
    time_elapsed = str(new_current_time - current_time)
    current_time = new_current_time
    print("Iteration {}: time = {} last_best_loss = {}, this_loss = {}".format(
              i, time_elapsed, last_best_loss, this_loss))
    
    print("prev = {}\nnext = {}\npred_prev = {}\npred_next = {}".format(
        d.convert_indices_to_sentences(prev),
        d.convert_indices_to_sentences(nex),
        d.convert_indices_to_sentences(prev_pred),
        d.convert_indices_to_sentences(next_pred),
    ))
    
    try:
        trail_loss = sum(loss_trail)/len(loss_trail)
        if last_best_loss is None or last_best_loss > trail_loss:
            print("Loss improved from {} to {}".format(last_best_loss, trail_loss))
            
            save_loc = "uni_skip.npz".format(lr, VOCAB_SIZE)
            print("saving model at {}".format(save_loc))
            torch.save(mod.state_dict(), save_loc)
            
            

          #  with open("model_DUMP.txt","wb") as file:
          #      model_file=pickle.dump(mod,file)
                
          #  with open(“DUMPS/model_DUMP.txt”,“rb”) as mod:    #when loading model use this
          #      existing_model = pickle.load(mod)    
            
      #      files.download(mod.state_dict())
            last_best_loss = trail_loss
            
            
    except Exception as e:
       print("Couldn't save model because {}".format(e))

# %%
print("Starting training...")

DEVICES=[0]
print(CUDA_DEVICE)
for i in range(0, 1000):
    sentences, lengths = d.fetch_batch(2*2)

    loss, prev, nex, prev_pred, next_pred  = mod(sentences, lengths)
    

    if i % 10 == 0:
        debug(i, loss, prev, nex, prev_pred, next_pred)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Starting training...
# 2
# Iteration 0: time = 0:00:09.365988 last_best_loss = None, this_loss = 18.685880661010742
# prev = 0000000000001011 EOS EOS
# next = 0000000000010111 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001101 0000000000001101 0000000000001101
# Loss improved from None to 18.685880661010742
# saving model at uni_skip.npz
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   del sys.path[0]
# /content/data_loader.py:63: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   idx = idx.data[0]
# Iteration 10: time = 0:00:09.107549 last_best_loss = 18.685880661010742, this_loss = 18.21508026123047
# prev = 0000000001001000 EOS EOS
# next = 0000000001010110 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 18.685880661010742 to 18.450481414794922
# saving model at uni_skip.npz
# Iteration 20: time = 0:00:08.930993 last_best_loss = 18.450481414794922, this_loss = 18.323740005493164
# prev = 0000000000110101 EOS EOS
# next = 0000000000101110 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 18.450481414794922 to 18.408233642578125
# saving model at uni_skip.npz
# Iteration 30: time = 0:00:09.009751 last_best_loss = 18.408233642578125, this_loss = 17.553451538085938
# prev = 0000000000011101 EOS EOS
# next = 0000000000010011 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 18.408233642578125 to 18.194538116455078
# saving model at uni_skip.npz
# Iteration 40: time = 0:00:08.762544 last_best_loss = 18.194538116455078, this_loss = 19.126564025878906
# prev = 0000000010001010 EOS EOS
# next = 0000000000101100 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 50: time = 0:00:08.489496 last_best_loss = 18.194538116455078, this_loss = 19.758045196533203
# prev = 0000000000011010 EOS EOS
# next = 0000000011000100 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 60: time = 0:00:08.485204 last_best_loss = 18.194538116455078, this_loss = 19.46422004699707
# prev = 0000000000110010 EOS EOS
# next = 0000000000101111 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 70: time = 0:00:08.503738 last_best_loss = 18.194538116455078, this_loss = 16.256813049316406
# prev = 0000000000100111 EOS EOS
# next = 0000000000111010 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000010011
# Iteration 80: time = 0:00:08.492082 last_best_loss = 18.194538116455078, this_loss = 16.565715789794922
# prev = 0000000000001010 EOS EOS
# next = 0000000000010111 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 90: time = 0:00:08.471258 last_best_loss = 18.194538116455078, this_loss = 17.22762107849121
# prev = 0000000000010101 EOS EOS
# next = 0000000000001100 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 18.194538116455078 to 18.117712020874023
# saving model at uni_skip.npz
# Iteration 100: time = 0:00:08.732728 last_best_loss = 18.117712020874023, this_loss = 17.57178497314453
# prev = 0000000001010000 EOS EOS
# next = 0000000000111111 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 18.117712020874023 to 18.068082809448242
# saving model at uni_skip.npz
# Iteration 110: time = 0:00:08.756607 last_best_loss = 18.068082809448242, this_loss = 16.430696487426758
# prev = 0000000001100110 EOS EOS
# next = 0000000000010010 EOS EOS
# pred_prev = 0000000000001101 0000000000001101 0000000000001101
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 18.068082809448242 to 17.93163299560547
# saving model at uni_skip.npz
# Iteration 120: time = 0:00:08.744043 last_best_loss = 17.93163299560547, this_loss = 17.710283279418945
# prev = 0000000011011111 EOS EOS
# next = 0000000001001110 EOS EOS
# pred_prev = 0000000000001101 0000000000001101 0000000000001101
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 17.93163299560547 to 17.91460609436035
# saving model at uni_skip.npz
# Iteration 130: time = 0:00:09.105466 last_best_loss = 17.91460609436035, this_loss = 17.28525161743164
# prev = 0000000001110010 EOS EOS
# next = 0000000001001110 EOS EOS
# pred_prev = 0000000000001101 0000000000001101 0000000000001101
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 17.91460609436035 to 17.869651794433594
# saving model at uni_skip.npz
# Iteration 140: time = 0:00:08.801401 last_best_loss = 17.869651794433594, this_loss = 16.827049255371094
# prev = 0000000000111111 EOS EOS
# next = 0000000000100010 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 17.869651794433594 to 17.80014419555664
# saving model at uni_skip.npz
# Iteration 150: time = 0:00:08.812922 last_best_loss = 17.80014419555664, this_loss = 16.55356216430664
# prev = 0000000001010000 EOS EOS
# next = 0000000000011000 EOS EOS
# pred_prev = 0000000000001101 0000000000001101 0000000000001101
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 17.80014419555664 to 17.722232818603516
# saving model at uni_skip.npz
# Iteration 160: time = 0:00:08.780856 last_best_loss = 17.722232818603516, this_loss = 16.64167022705078
# prev = 0000000000001100 EOS EOS
# next = 0000000000001110 EOS EOS
# pred_prev = 0000000000001101 0000000000001101 0000000000001101
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 17.722232818603516 to 17.65867042541504
# saving model at uni_skip.npz
# Iteration 170: time = 0:00:08.783624 last_best_loss = 17.65867042541504, this_loss = 17.469158172607422
# prev = 0000000000001100 EOS EOS
# next = 0000000011000101 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 17.65867042541504 to 17.64813995361328
# saving model at uni_skip.npz
# Iteration 180: time = 0:00:08.779130 last_best_loss = 17.64813995361328, this_loss = 16.55097198486328
# prev = 0000000010110000 EOS EOS
# next = 0000000000001100 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 17.64813995361328 to 17.590394973754883
# saving model at uni_skip.npz
# Iteration 190: time = 0:00:08.754875 last_best_loss = 17.590394973754883, this_loss = 16.92142105102539
# prev = 0000000001100100 EOS EOS
# next = 0000000000010000 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 17.590394973754883 to 17.55694580078125
# saving model at uni_skip.npz
# Iteration 200: time = 0:00:08.835705 last_best_loss = 17.55694580078125, this_loss = 16.968896865844727
# prev = 0000000000001110 EOS EOS
# next = 0000000010011101 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 17.55694580078125 to 17.47109603881836
# saving model at uni_skip.npz
# Iteration 210: time = 0:00:08.802588 last_best_loss = 17.47109603881836, this_loss = 18.129371643066406
# prev = 0000000001011111 EOS EOS
# next = 0000000010010111 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 17.47109603881836 to 17.46681022644043
# saving model at uni_skip.npz
# Iteration 220: time = 0:00:08.801618 last_best_loss = 17.46681022644043, this_loss = 17.005184173583984
# prev = 0000000010101010 EOS EOS
# next = 0000000000111011 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 17.46681022644043 to 17.4008846282959
# saving model at uni_skip.npz
# Iteration 230: time = 0:00:08.821534 last_best_loss = 17.4008846282959, this_loss = 16.87657928466797
# prev = 0000000000110110 EOS EOS
# next = 0000000000001010 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Loss improved from 17.4008846282959 to 17.367042541503906
# saving model at uni_skip.npz
# Iteration 240: time = 0:00:09.073833 last_best_loss = 17.367042541503906, this_loss = 17.19573402404785
# prev = 0000000010111011 EOS EOS
# next = 0000000011111010 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Loss improved from 17.367042541503906 to 17.2705020904541
# saving model at uni_skip.npz
# Iteration 250: time = 0:00:08.805004 last_best_loss = 17.2705020904541, this_loss = 17.602962493896484
# prev = 0000000000001010 EOS EOS
# next = 0000000011101010 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Loss improved from 17.2705020904541 to 17.16274642944336
# saving model at uni_skip.npz
# Iteration 260: time = 0:00:08.771783 last_best_loss = 17.16274642944336, this_loss = 16.2838134765625
# prev = 0000000000100100 EOS EOS
# next = 0000000000010101 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Loss improved from 17.16274642944336 to 17.003726959228516
# saving model at uni_skip.npz
# Iteration 270: time = 0:00:09.032655 last_best_loss = 17.003726959228516, this_loss = 16.307395935058594
# prev = 0000000000010100 EOS EOS
# next = 0000000011011010 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 280: time = 0:00:08.532485 last_best_loss = 17.003726959228516, this_loss = 16.547704696655273
# prev = 0000000001000000 EOS EOS
# next = 0000000000000110 EOS EOS
# pred_prev = 0000000000001010 0000000000001010 0000000000001010
# pred_next = 0000000000001010 0000000000001010 0000000000001110
# Iteration 290: time = 0:00:08.874616 last_best_loss = 17.003726959228516, this_loss = 16.672454833984375
# prev = 0000000001100001 EOS EOS
# next = 0000000001011111 EOS EOS
# pred_prev = 0000000000001010 0000000000001010 0000000000001010
# pred_next = 0000000000001010 0000000000001010 0000000000001010
# Loss improved from 17.003726959228516 to 16.977598190307617
# saving model at uni_skip.npz
# Iteration 300: time = 0:00:08.792905 last_best_loss = 16.977598190307617, this_loss = 17.975704193115234
# prev = 0000000000001101 EOS EOS
# next = 0000000011110010 EOS EOS
# pred_prev = 0000000000001010 0000000000001010 0000000000001010
# pred_next = 0000000000001010 0000000000001010 0000000000001010
# Iteration 310: time = 0:00:08.515351 last_best_loss = 16.977598190307617, this_loss = 17.378124237060547
# prev = 0000000000010111 EOS EOS
# next = 0000000010010100 EOS EOS
# pred_prev = 0000000000001010 0000000000001010 0000000000001010
# pred_next = 0000000000001010 0000000000001010 0000000000001010
# Iteration 320: time = 0:00:08.517265 last_best_loss = 16.977598190307617, this_loss = 17.209980010986328
# prev = 0000000010111011 EOS EOS
# next = 0000000010010011 EOS EOS
# pred_prev = 0000000000001010 0000000000001010 0000000000001010
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 330: time = 0:00:08.537214 last_best_loss = 16.977598190307617, this_loss = 16.769100189208984
# prev = 0000000010011001 EOS EOS
# next = 0000000011011001 EOS EOS
# pred_prev = 0000000000001010 0000000000001010 0000000000001010
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 340: time = 0:00:08.554467 last_best_loss = 16.977598190307617, this_loss = 17.38429069519043
# prev = 0000000000001011 EOS EOS
# next = 0000000001000100 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 350: time = 0:00:08.526949 last_best_loss = 16.977598190307617, this_loss = 16.19903564453125
# prev = 0000000010110000 EOS EOS
# next = 0000000000001101 EOS EOS
# pred_prev = 0000000000010001 0000000000010001 0000000000010001
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 360: time = 0:00:08.498220 last_best_loss = 16.977598190307617, this_loss = 17.409557342529297
# prev = 0000000000001110 EOS EOS
# next = 0000000010001110 EOS EOS
# pred_prev = 0000000000010001 0000000000010001 0000000000010001
# pred_next = 0000000000010001 0000000000010001 0000000000010001
# Iteration 370: time = 0:00:08.515672 last_best_loss = 16.977598190307617, this_loss = 17.04723358154297
# prev = 0000000001001101 EOS EOS
# next = 0000000001010101 EOS EOS
# pred_prev = 0000000000010001 0000000000010001 0000000000010001
# pred_next = 0000000000010001 0000000000010001 0000000000010001
# Iteration 380: time = 0:00:08.513761 last_best_loss = 16.977598190307617, this_loss = 17.078571319580078
# prev = 0000000000111000 EOS EOS
# next = 0000000001011000 EOS EOS
# pred_prev = 0000000000010001 0000000000010001 0000000000010001
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 390: time = 0:00:08.565989 last_best_loss = 16.977598190307617, this_loss = 16.545194625854492
# prev = 0000000000010010 EOS EOS
# next = 0000000001000100 EOS EOS
# pred_prev = 0000000000010001 0000000000010001 0000000000010001
# pred_next = 0000000000010001 0000000000010001 0000000000010001
# Iteration 400: time = 0:00:08.561608 last_best_loss = 16.977598190307617, this_loss = 16.320972442626953
# prev = 0000000000111111 EOS EOS
# next = 0000000000010010 EOS EOS
# pred_prev = 0000000000010001 0000000000010001 0000000000010001
# pred_next = 0000000000010001 0000000000010001 0000000000010001
# Iteration 410: time = 0:00:08.607843 last_best_loss = 16.977598190307617, this_loss = 17.00347900390625
# prev = 0000000011111110 EOS EOS
# next = 0000000010111101 EOS EOS
# pred_prev = 0000000000010001 0000000000010001 0000000000010001
# pred_next = 0000000000010001 0000000000010001 0000000000010001
# Loss improved from 16.977598190307617 to 16.940654754638672
# saving model at uni_skip.npz
# Iteration 420: time = 0:00:08.908619 last_best_loss = 16.940654754638672, this_loss = 16.70587921142578
# prev = 0000000000010001 EOS EOS
# next = 0000000010101110 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 16.940654754638672 to 16.925689697265625
# saving model at uni_skip.npz
# Iteration 430: time = 0:00:08.884028 last_best_loss = 16.925689697265625, this_loss = 17.348896026611328
# prev = 0000000001110011 EOS EOS
# next = 0000000010101110 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 440: time = 0:00:08.587328 last_best_loss = 16.925689697265625, this_loss = 16.34160614013672
# prev = 0000000000001110 EOS EOS
# next = 0000000010110010 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 16.925689697265625 to 16.906597137451172
# saving model at uni_skip.npz
# Iteration 450: time = 0:00:09.021213 last_best_loss = 16.906597137451172, this_loss = 16.664581298828125
# prev = 0000000011011000 EOS EOS
# next = 0000000000010001 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 16.906597137451172 to 16.85968017578125
# saving model at uni_skip.npz
# Iteration 460: time = 0:00:08.901086 last_best_loss = 16.85968017578125, this_loss = 18.093793869018555
# prev = 0000000011001100 EOS EOS
# next = 0000000011001101 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 470: time = 0:00:08.589033 last_best_loss = 16.85968017578125, this_loss = 16.415210723876953
# prev = 0000000011111001 EOS EOS
# next = 0000000000001111 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 480: time = 0:00:08.683266 last_best_loss = 16.85968017578125, this_loss = 16.56623077392578
# prev = 0000000000010000 EOS EOS
# next = 0000000000001011 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 490: time = 0:00:08.597697 last_best_loss = 16.85968017578125, this_loss = 17.02456283569336
# prev = 0000000011011101 EOS EOS
# next = 0000000000001100 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 500: time = 0:00:08.565620 last_best_loss = 16.85968017578125, this_loss = 16.469038009643555
# prev = 0000000001011100 EOS EOS
# next = 0000000000001101 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 510: time = 0:00:08.535168 last_best_loss = 16.85968017578125, this_loss = 16.27728271484375
# prev = 0000000000011001 EOS EOS
# next = 0000000000001110 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 16.85968017578125 to 16.84372329711914
# saving model at uni_skip.npz
# Iteration 520: time = 0:00:08.866965 last_best_loss = 16.84372329711914, this_loss = 17.32265281677246
# prev = 0000000001011100 EOS EOS
# next = 0000000001010100 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 530: time = 0:00:08.520553 last_best_loss = 16.84372329711914, this_loss = 17.25841522216797
# prev = 0000000001011001 EOS EOS
# next = 0000000010100010 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 540: time = 0:00:08.542509 last_best_loss = 16.84372329711914, this_loss = 15.745370864868164
# prev = 0000000000010010 EOS EOS
# next = 0000000000001111 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Loss improved from 16.84372329711914 to 16.79187774658203
# saving model at uni_skip.npz
# Iteration 550: time = 0:00:08.913362 last_best_loss = 16.79187774658203, this_loss = 17.463134765625
# prev = 0000000011000110 EOS EOS
# next = 0000000001100010 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 560: time = 0:00:08.578418 last_best_loss = 16.79187774658203, this_loss = 16.103267669677734
# prev = 0000000010110010 EOS EOS
# next = 0000000010001010 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 16.79187774658203 to 16.78976821899414
# saving model at uni_skip.npz
# Iteration 570: time = 0:00:08.886955 last_best_loss = 16.78976821899414, this_loss = 17.468673706054688
# prev = 0000000000100011 EOS EOS
# next = 0000000001111110 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 580: time = 0:00:08.552807 last_best_loss = 16.78976821899414, this_loss = 17.561824798583984
# prev = 0000000010100111 EOS EOS
# next = 0000000010101000 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 590: time = 0:00:08.546539 last_best_loss = 16.78976821899414, this_loss = 16.27581024169922
# prev = 0000000000001100 EOS EOS
# next = 0000000000010011 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 600: time = 0:00:08.538461 last_best_loss = 16.78976821899414, this_loss = 17.132646560668945
# prev = 0000000001000110 EOS EOS
# next = 0000000010001000 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 610: time = 0:00:08.546309 last_best_loss = 16.78976821899414, this_loss = 17.195533752441406
# prev = 0000000000011111 EOS EOS
# next = 0000000011100010 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 620: time = 0:00:08.592523 last_best_loss = 16.78976821899414, this_loss = 16.32465362548828
# prev = 0000000000010010 EOS EOS
# next = 0000000011101100 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 630: time = 0:00:08.595619 last_best_loss = 16.78976821899414, this_loss = 17.38703727722168
# prev = 0000000001011101 EOS EOS
# next = 0000000010100000 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 640: time = 0:00:08.573369 last_best_loss = 16.78976821899414, this_loss = 16.443050384521484
# prev = 0000000011010001 EOS EOS
# next = 0000000000001110 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 650: time = 0:00:08.557753 last_best_loss = 16.78976821899414, this_loss = 16.533306121826172
# prev = 0000000001001110 EOS EOS
# next = 0000000010101000 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 660: time = 0:00:08.553458 last_best_loss = 16.78976821899414, this_loss = 17.306007385253906
# prev = 0000000001111010 EOS EOS
# next = 0000000001100111 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 670: time = 0:00:08.550037 last_best_loss = 16.78976821899414, this_loss = 16.206607818603516
# prev = 0000000011011110 EOS EOS
# next = 0000000010100100 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 680: time = 0:00:08.583500 last_best_loss = 16.78976821899414, this_loss = 17.14305305480957
# prev = 0000000001010010 EOS EOS
# next = 0000000001100011 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 690: time = 0:00:08.597896 last_best_loss = 16.78976821899414, this_loss = 16.58719825744629
# prev = 0000000010001101 EOS EOS
# next = 0000000000001110 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 700: time = 0:00:08.609660 last_best_loss = 16.78976821899414, this_loss = 17.08323097229004
# prev = 0000000011001110 EOS EOS
# next = 0000000001100100 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 710: time = 0:00:08.581809 last_best_loss = 16.78976821899414, this_loss = 16.795604705810547
# prev = 0000000000011111 EOS EOS
# next = 0000000000100111 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 720: time = 0:00:08.538424 last_best_loss = 16.78976821899414, this_loss = 16.74436378479004
# prev = 0000000010110000 EOS EOS
# next = 0000000011001011 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 730: time = 0:00:08.457012 last_best_loss = 16.78976821899414, this_loss = 16.852214813232422
# prev = 0000000000001010 EOS EOS
# next = 0000000011000111 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 740: time = 0:00:08.479992 last_best_loss = 16.78976821899414, this_loss = 15.982892990112305
# prev = 0000000000001100 EOS EOS
# next = 0000000000010001 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 750: time = 0:00:08.507483 last_best_loss = 16.78976821899414, this_loss = 16.90066146850586
# prev = 0000000000001101 EOS EOS
# next = 0000000001000011 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 760: time = 0:00:08.517122 last_best_loss = 16.78976821899414, this_loss = 16.522483825683594
# prev = 0000000000100110 EOS EOS
# next = 0000000011100101 EOS EOS
# pred_prev = 0000000000001100 0000000000010001 0000000000010001
# pred_next = 0000000000010001 0000000000010001 0000000000010001
# Iteration 770: time = 0:00:08.499343 last_best_loss = 16.78976821899414, this_loss = 16.796768188476562
# prev = 0000000000010001 EOS EOS
# next = 0000000010111011 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 16.78976821899414 to 16.788747787475586
# saving model at uni_skip.npz
# Iteration 780: time = 0:00:09.098089 last_best_loss = 16.788747787475586, this_loss = 16.577392578125
# prev = 0000000010000000 EOS EOS
# next = 0000000001100010 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 16.788747787475586 to 16.739526748657227
# saving model at uni_skip.npz
# Iteration 790: time = 0:00:08.840903 last_best_loss = 16.739526748657227, this_loss = 17.3131103515625
# prev = 0000000001100000 EOS EOS
# next = 0000000001110011 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 800: time = 0:00:08.508194 last_best_loss = 16.739526748657227, this_loss = 18.067533493041992
# prev = 0000000010000000 EOS EOS
# next = 0000000010011100 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 810: time = 0:00:08.508796 last_best_loss = 16.739526748657227, this_loss = 16.79175567626953
# prev = 0000000000101000 EOS EOS
# next = 0000000000100111 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 820: time = 0:00:08.495341 last_best_loss = 16.739526748657227, this_loss = 15.900331497192383
# prev = 0000000000111010 EOS EOS
# next = 0000000000001100 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 830: time = 0:00:08.518613 last_best_loss = 16.739526748657227, this_loss = 16.56216049194336
# prev = 0000000010010110 EOS EOS
# next = 0000000010111101 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 840: time = 0:00:08.523761 last_best_loss = 16.739526748657227, this_loss = 16.404617309570312
# prev = 0000000000001100 EOS EOS
# next = 0000000010110011 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 850: time = 0:00:08.526207 last_best_loss = 16.739526748657227, this_loss = 16.463191986083984
# prev = 0000000010110101 EOS EOS
# next = 0000000011010111 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 860: time = 0:00:08.479797 last_best_loss = 16.739526748657227, this_loss = 16.843318939208984
# prev = 0000000000100000 EOS EOS
# next = 0000000000010010 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Loss improved from 16.739526748657227 to 16.726924896240234
# saving model at uni_skip.npz
# Iteration 870: time = 0:00:08.821467 last_best_loss = 16.726924896240234, this_loss = 16.333131790161133
# prev = 0000000000001100 EOS EOS
# next = 0000000000100100 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001110 0000000000001110 0000000000001110
# Iteration 880: time = 0:00:08.464254 last_best_loss = 16.726924896240234, this_loss = 16.47931671142578
# prev = 0000000000010110 EOS EOS
# next = 0000000000111111 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001110 0000000000001110 0000000000001100
# Loss improved from 16.726924896240234 to 16.700063705444336
# saving model at uni_skip.npz
# Iteration 890: time = 0:00:08.882149 last_best_loss = 16.700063705444336, this_loss = 17.043058395385742
# prev = 0000000001111111 EOS EOS
# next = 0000000001100010 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 900: time = 0:00:08.522032 last_best_loss = 16.700063705444336, this_loss = 16.480422973632812
# prev = 0000000011111001 EOS EOS
# next = 0000000000001100 EOS EOS
# pred_prev = 0000000000001110 0000000000001101 0000000000001110
# pred_next = 0000000000001110 0000000000001100 0000000000001110
# Loss improved from 16.700063705444336 to 16.69271469116211
# saving model at uni_skip.npz
# Iteration 910: time = 0:00:08.827079 last_best_loss = 16.69271469116211, this_loss = 16.663570404052734
# prev = 0000000011110011 EOS EOS
# next = 0000000001100010 EOS EOS
# pred_prev = 0000000000001101 0000000000001101 0000000000001101
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 16.69271469116211 to 16.686115264892578
# saving model at uni_skip.npz
# Iteration 920: time = 0:00:08.854940 last_best_loss = 16.686115264892578, this_loss = 15.890613555908203
# prev = 0000000000100111 EOS EOS
# next = 0000000000010001 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 16.686115264892578 to 16.643428802490234
# saving model at uni_skip.npz
# Iteration 930: time = 0:00:08.825931 last_best_loss = 16.643428802490234, this_loss = 16.537620544433594
# prev = 0000000000001100 EOS EOS
# next = 0000000001100011 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Loss improved from 16.643428802490234 to 16.62769889831543
# saving model at uni_skip.npz
# Iteration 940: time = 0:00:08.799335 last_best_loss = 16.62769889831543, this_loss = 17.653480529785156
# prev = 0000000011100001 EOS EOS
# next = 0000000011001111 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 950: time = 0:00:08.454165 last_best_loss = 16.62769889831543, this_loss = 16.234006881713867
# prev = 0000000000111111 EOS EOS
# next = 0000000000000111 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 960: time = 0:00:08.461659 last_best_loss = 16.62769889831543, this_loss = 17.22337532043457
# prev = 0000000010101000 EOS EOS
# next = 0000000001111001 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 970: time = 0:00:08.503112 last_best_loss = 16.62769889831543, this_loss = 16.630680084228516
# prev = 0000000000001110 EOS EOS
# next = 0000000001100101 EOS EOS
# pred_prev = 0000000000001100 0000000000001100 0000000000001100
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 980: time = 0:00:08.496063 last_best_loss = 16.62769889831543, this_loss = 16.7366886138916
# prev = 0000000000001101 EOS EOS
# next = 0000000010100011 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100
# Iteration 990: time = 0:00:08.516669 last_best_loss = 16.62769889831543, this_loss = 17.330158233642578
# prev = 0000000001110101 EOS EOS
# next = 0000000000000101 EOS EOS
# pred_prev = 0000000000001110 0000000000001110 0000000000001110
# pred_next = 0000000000001100 0000000000001100 0000000000001100

# %% [markdown]
# # New Section

# %%
from model import UniSkip, Encoder
from data_loader import DataLoader
from vocab import load_dictionary
from config import *
from torch import nn
import pickle
from glob import *
from torch.autograd import Variable
import torch

import os

class UsableEncoder:
    import glob
    file_list=glob.glob("gdrive/My Drive/Colab Notebooks/mdata/***.txt")

corpus = []

for file_path in file_list:
    with open(file_path) as f_input:
        corpus.append(f_input.readlines())
    
       
    def __init__(self, loc="uni_skip.npz"):
        import glob
        file_list=glob.glob("gdrive/My Drive/Colab Notebooks/mdata/***.pkl")

        corpus = []

        for file_path in file_list:
            #with open(file_path) as f_input:
                #corpus.append(f_input.readlines())
             #encoding='utf8'
            print("Preparing the DataLoader. Loading the word dictionary")
            self.d = DataLoader(sentences=[''], word_dict=load_dictionary(file_path))
            self.encoder = None
        
            print("Loading encoder from the saved model at {}".format(loc))
            model = UniSkip()
            model.load_state_dict(torch.load(loc, map_location=lambda storage, loc: storage))
            self.encoder = model.encoder
            if USE_CUDA:
              self.encoder.cuda(CUDA_DEVICE)
    
    def encode(self, text):
        def chunks(l, n):
            """Yield successive n-sized chunks from l."""
            for i in range(0, len(l), n):
                yield l[i:i + n]
        
        ret = []
        
        for chunk in chunks(text, 100):
            print("encoding chunk of size {}".format(len(chunk)))
            indices = [self.d.convert_sentence_to_indices(sentence) for sentence in chunk]
            indices = torch.stack(indices)
            indices, _ = self.encoder(indices)
            indices = indices.view(-1, self.encoder.thought_size)
            indices = indices.data.cpu().numpy()
            
            ret.extend(indices)
        ret = np.array(ret)
        print("done file ")
        np.save('utable.npy', array_lst)
        
        return ret

    usable_encoder = UsableEncoder()
    print(usable_encoder)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-6cf57751a5bc> in <module>()
#       1 from model import UniSkip, Encoder
# ----> 2 from data_loader import DataLoader
#       3 from vocab import load_dictionary
#       4 from config import *
#       5 from torch import nn
#
# ImportError: cannot import name 'DataLoader'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch
# Out:
# tcmalloc: large alloc 1073750016 bytes == 0x58fa8000 @  0x7f5f6b3342a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641

# %%
import _pickle as pkl
import glob
from collections import OrderedDict
import argparse

file_list=glob.glob("gdrive/My Drive/Colab Notebooks/mdata/***.txt")

corpus = []

for file_path in file_list:
    with open(file_path) as f_input:
        corpus.append(f_input.readlines())

# %%
# Out:
# usage: ipykernel_launcher.py [-h] text_file
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
